# %%
# import libraries
import sqlite3
import pandas as pd
import os
import ast

# %%
# setup sqlite connection
con = sqlite3.connect('../airflow/airflow.db')
cur = con.cursor()

# %%
# prepare player files and load into df
file_list = os.listdir('../RawText')
game_files = [x for x in file_list if x.startswith('games')]
li = []
for file in game_files:
    df=pd.read_csv(f'../RawText/{file}')
    li.append(df)
games_raw = pd.concat(li)

# %%
# extract teamid from team dictionary
games_raw['HomeTeamID'] = games_raw.apply(lambda row: ast.literal_eval(row['home_team'])['id'], axis=1)

# %%
games_raw.head()
# Out:
#        id                      date  \
# 0  127502  2020-12-22T00:00:00.000Z
# 1  127503  2020-12-22T00:00:00.000Z
# 2  127519  2020-12-25T00:00:00.000Z
# 3  127526  2020-12-26T00:00:00.000Z
# 4  127504  2020-12-23T00:00:00.000Z
#
#                                            home_team  home_team_score  period  \
# 0  {'id': 3, 'abbreviation': 'BKN', 'city': 'Broo...              125       4
# 1  {'id': 14, 'abbreviation': 'LAL', 'city': 'Los...              109       4
# 2  {'id': 16, 'abbreviation': 'MIA', 'city': 'Mia...              111       4
# 3  {'id': 30, 'abbreviation': 'WAS', 'city': 'Was...              120       4
# 4  {'id': 6, 'abbreviation': 'CLE', 'city': 'Clev...              121       4
#
#    postseason  season status time  \
# 0       False    2020  Final  NaN
# 1       False    2020  Final  NaN
# 2       False    2020  Final  NaN
# 3       False    2020  Final  NaN
# 4       False    2020  Final  NaN
#
#                                         visitor_team  visitor_team_score  \
# 0  {'id': 10, 'abbreviation': 'GSW', 'city': 'Gol...                  99
# 1  {'id': 13, 'abbreviation': 'LAC', 'city': 'LA'...                 116
# 2  {'id': 19, 'abbreviation': 'NOP', 'city': 'New...                  98
# 3  {'id': 22, 'abbreviation': 'ORL', 'city': 'Orl...                 130
# 4  {'id': 4, 'abbreviation': 'CHA', 'city': 'Char...                 114
#
#    HomeTeamID
# 0           3
# 1          14
# 2          16
# 3          30
# 4           6

# %%
# prepare player files and load into df
file_list = os.listdir('../RawText')
player_files = [x for x in file_list if x.startswith('players')]
li = []
for file in player_files:
    df=pd.read_csv(f'../RawText/{file}')
    li.append(df)
players_raw = pd.concat(li)
